# %%
#NUMERO 1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Visualizar las primeras filas y la infromación general de la data

#print(df.head(8))
#print(df.info())
print()


#Eliminar duplicados
df=df.drop_duplicates()
#print("Resgitros duplicados eliminados")
print()
#print(df.info())


#Analitica descriptiva no grafica:

#Calcular la moda de la variable lugar
moda_lugar=df['LUGAR_DE_ESTUDIO'].mode()[0]
print("Lugar de estudio más preferido por loes estudiantes Unisinuanos: "+moda_lugar)
print()
print()
contar_lugares=df['LUGAR_DE_ESTUDIO'].value_counts()
#print("Conteo de lugares preferidos: ")
print()
#print(contar_lugares)
print()
print()

#Contar cuantos estudinates de cada carrera asisten a cada lugar
carrera_lugares=df.groupby(["CARRERA","LUGAR_DE_ESTUDIO"])["LUGAR_DE_ESTUDIO"].count()
#print(carrera_lugares)
print()
print()

#Caclcular el lugar de preferencia por carrera
preferencias_carreras_lugares = df.groupby("CARRERA")["LUGAR_DE_ESTUDIO"].agg(lambda x: x.mode()[0])
print("Lugares mas escogidos por carreras:")
print(preferencias_carreras_lugares)
print()



#NUMERO 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Contar frecuencia de lugares
contar_lugares=df['LUGAR_DE_ESTUDIO'].value_counts()
print(contar_lugares)

#Grafica de barras de frecuencia de lugares de estudio
plt.figure(figsize=(10,5))  
contar_lugares.plot(kind='bar', color='coral')
plt.title("Distribución de Lugares de Estudio")
plt.xlabel("Lugar de Estudio")
plt.ylabel("Frecuencia")
plt.show()




#NUMERO 3

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Promedio de horas de estudio:
Prom_horas_de_estudio= df.HORAS_DE_ESTUDIO.mean()
print("Promedio de horas de estudio de los estudiantes unisinuanos:\n", Prom_horas_de_estudio)
#Promedio de horas de estudio por lugar de estudio
Prom_horas_lugar = df.groupby("LUGAR_DE_ESTUDIO")["HORAS_DE_ESTUDIO"].mean()
print()
print()
print("Promedio de horas por lugar de estudio:\n", Prom_horas_lugar)
print()




#NUMERO 4

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Promedio de horas de estudio por carrera
Prom_horas_carrera= df.groupby("CARRERA")["HORAS_DE_ESTUDIO"].mean()
print("¿Que carrera estudia mas en la unisinu?\n\n")
print("Promedio de horas de estudio por carrera: \n",Prom_horas_carrera)
print()
print()

#Promedio de horas por carrera y lugar de estudio
Prom_lugar_carrera_hora=df.groupby(["CARRERA", "LUGAR_DE_ESTUDIO"])["HORAS_DE_ESTUDIO"].mean()
print("Promedio de horas por carrera y lugar de estudio \n",Prom_lugar_carrera_hora)
print()
print()
print()

#NUMERO 5

#Mediana de las horas de estudio
Mediana_horas= df.HORAS_DE_ESTUDIO.median()
print("Mediana de las horas de estudio:\n",Mediana_horas)
print()
print()

#Mediana por lugar de estudio
mediana_por_lugar = df.groupby("LUGAR_DE_ESTUDIO")["HORAS_DE_ESTUDIO"].median()
print("Mediana de las horas de estudio por lugar de estudio:\n",mediana_por_lugar)
print()
print()
#Media de las horas de estudio
media_lugar_de_estudio= df.HORAS_DE_ESTUDIO.mean()
print("Media de las horas de eestudio: ",media_lugar_de_estudio)
print()
print()

# Calcular la desviación estándar de las horas de estudio
desviacion_estandar_horas = df["HORAS_DE_ESTUDIO"].std()
print(f"Desviación estándar de las horas de estudio: {desviacion_estandar_horas:.2f}")
print()
print()

#Calcular desviacion baja o alta
Nivel_desvicacion_horas=desviacion_estandar_horas / media_lugar_de_estudio;
Porcentaje_Nivel_desviacion_horas=Nivel_desvicacion_horas *100;
print("Nivel de desviacion estandar de las horas de estudio:",Porcentaje_Nivel_desviacion_horas,"%")
print()
print()




#NUMERO 6

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Promedio de puntuacion
Puntuacion= df.PUNTUACION.mean()
print("Puntuacion promedio de los lugares de estudio: ",Puntuacion)
print()

Puntuacion_por_lugar=df.groupby("LUGAR_DE_ESTUDIO")["PUNTUACION"].mean()
print("Puntuacion por lugar de estudio:")
print(Puntuacion_por_lugar)



#NUMERO 7 
#CALCULAR LOS VALORES ATIPICOS QUE SE ENCUENTRAN EN LA DATA
# Calcular los cuartiles
Q1 = df["HORAS_DE_ESTUDIO"].quantile(0.25)
Q3 = df["HORAS_DE_ESTUDIO"].quantile(0.75)
print("Cuartil del 25%",Q1)
print("Cuartil del 75%",Q3)

# Calcular el rango intercuartílico (IQR)
IQR = Q3 - Q1

# Definir los límites para outliers
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

print(f"Límite inferior: {limite_inferior:.2f}, Límite superior: {limite_superior:.2f}")


#Filtrar los valores atipicos
outliers = df[(df["HORAS_DE_ESTUDIO"] < limite_inferior) | (df["HORAS_DE_ESTUDIO"] > limite_superior)]
print("Valores atípicos detectados:")
print(outliers)

#Boxplot de horas de estudio, para evidenciar el outlier detectado arriba
import seaborn as sns

plt.figure(figsize=(8,5))
sns.boxplot(x=df["HORAS_DE_ESTUDIO"])
plt.title("Detección de Valores Atípicos en Horas de Estudio")
plt.show()


plt.figure(figsize=(8,5))
sns.boxplot(x=df["PUNTUACION"])
plt.title("Detección de Valores Atípicos en Puntuación")
plt.show()




#NUMERO 8

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Contar frecuencia de lugares
contar_puntuacion=df['PUNTUACION'].value_counts()
print("Conteo de puntuacion: \n",contar_puntuacion)

#Grafica de barras de distribucion de puntuacion
plt.figure(figsize=(10,5))  
contar_puntuacion.plot(kind='bar', color='coral')
plt.title("Distribución de Puntuacion")
plt.xlabel("Puntuacion")
plt.ylabel("Frecuencia")
plt.show()
print()
print()
print()
#Grafica de pastel de distribucion de puntuacion
plt.figure(figsize=(10,5))
contar_puntuacion.plot(kind='pie', autopct='%1.1f%%', startangle=140, 
                       colors=plt.cm.Pastel1(np.linspace(0, 1, len(contar_puntuacion))))
plt.title("Distribución de Puntuación")
plt.ylabel("Frecuencia")
#plt.axis('equal')  # Asegura que el gráfico sea circular
plt.show()




#NUMERO 9

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Contar areas de estudio
print("¿Que es lo que mas estudian los estudiantes Unisinuanos?\n")
contar_asignaturas =df['AREA_DE_ESTUDIO'].value_counts()
print(contar_asignaturas)

#Histograma de el area de estudio mas frecuentada.
plt.figure(figsize=(30,8))
plt.subplot(2,2,1)
plt.hist(df['AREA_DE_ESTUDIO'], bins=30, color='skyblue', edgecolor='black')
plt.title('==Histograma de áreas de estudio==')
plt.xlabel('Área de estudio')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha="right")  # Rotar etiquetas para mayor legibilidad
plt.show()



#NUMERO 10

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Cargar el dataset a trabajar
df=pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#Moda de la variable "NUEVOS_ESPACIOS" para definir que prefieren los estudiantes, junto con moda de la variable
#"MEJORAS_SUGERIDAS" para comprobar que mejoras exigen y necesitan los estudiantes unisinuanos

moda_nuevos_espacios=df['NUEVOS_ESPACIOS'].mode()[0]
print("Los estudiantes necesitan mas lugares de estudio? : "+moda_nuevos_espacios)
print()
print()
contar_nuevos_espacios=df['NUEVOS_ESPACIOS'].value_counts()
print()
print("Aunque la mayoria de los estudiantes consideran que necesitan más ", moda_nuevos_espacios, "Tambien se presentan las otras opiniones del resto de estudinates")
print(contar_nuevos_espacios)
print()
print()

#Contar cuantos estudinates necesitan lugares
carrera_nuevos_espacios=df.groupby(["CARRERA","NUEVOS_ESPACIOS"])["NUEVOS_ESPACIOS"].count()
#print(carrera_nuevos_espacios)
print()
print()

#Caclcular el lugar de preferencia por carrera
preferencias_carreras_lugares = df.groupby("CARRERA")["NUEVOS_ESPACIOS"].agg(lambda x: x.mode()[0])
print("Espacios más necesitados por carreras: ")
print(preferencias_carreras_lugares)
print()


#Grafica de pastel de distribucion de puntuacion
plt.figure(figsize=(10,5))
contar_nuevos_espacios.plot(kind='pie', autopct='%1.1f%%', startangle=140, 
                       colors=plt.cm.Pastel1(np.linspace(0, 1, len(contar_puntuacion))))
plt.title("Distribución de Puntuación")
plt.ylabel("Frecuencia")
#plt.axis('equal')  # Asegura que el gráfico sea circular
plt.show()




#NUMERO 11

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar el dataset a trabajar
df = pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

# Moda de la variable "MEJORAS_SUGERIDAS" para definir cuáles son las mejoras que los estudiantes exigen y necesitan
moda_mejoras_sugeridas = df['MEJORAS_SUGERIDAS'].mode()[0]
print("¿Qué mejoras sugieren los estudiantes? : " + moda_mejoras_sugeridas)
print("\n")

# Contar frecuencia de las mejoras sugeridas
contar_mejoras_sugeridas = df['MEJORAS_SUGERIDAS'].value_counts()
print("Aunque la mayoría de los estudiantes sugieren ", moda_mejoras_sugeridas, 
      "también se presentan otras opiniones:")
print(contar_mejoras_sugeridas)
print("\n")

# Contar cuántos estudiantes sugieren cada tipo de mejora por carrera
carrera_mejoras_sugeridas = df.groupby(["CARRERA", "MEJORAS_SUGERIDAS"])["MEJORAS_SUGERIDAS"].count()
print("Conteo de mejoras sugeridas por carrera:")
#print(carrera_mejoras_sugeridas)
print("\n")

# Calcular la mejora de preferencia por carrera (moda por carrera)
preferencias_carreras_mejoras = df.groupby("CARRERA")["MEJORAS_SUGERIDAS"].agg(lambda x: x.mode()[0])
print("Mejoras más sugeridas por carrera:")
print(preferencias_carreras_mejoras)
print()


#Histograma de las mejoras sugeridas
plt.figure(figsize=(30,8))
plt.subplot(2,2,1)
plt.hist(df['MEJORAS_SUGERIDAS'], bins=30, color='skyblue', edgecolor='black')
plt.title('==Histograma de mejoras sugeridas==')
plt.xlabel('Mejora Sugerida')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45, ha="right")  # Rotar etiquetas para mayor legibilidad
plt.show()




#NUMERO 12

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset
df = pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

# Gráfico de barras con diferenciación por 'MEJORAS_SUGERIDAS'
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='LUGAR_DE_ESTUDIO', hue='MEJORAS_SUGERIDAS')
plt.title("Distribución de LUGAR_DE_ESTUDIO por MEJORAS_SUGERIDAS")
plt.xlabel("LUGAR_DE_ESTUDIO")
plt.ylabel("Conteo")
plt.xticks(rotation=90)
plt.legend(title="MEJORAS_SUGERIDAS")
plt.show()




#NUMERO 13

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset
df = pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

# Crear una tabla de contingencia entre 'MEJORAS_SUGERIDAS' y 'LUGAR_DE_ESTUDIO'
tabla = pd.crosstab(df['MEJORAS_SUGERIDAS'], df['LUGAR_DE_ESTUDIO'])

# Visualizar con heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(tabla, annot=True, cmap="YlGnBu", fmt="d")
plt.title("Distribución de MEJORAS_SUGERIDAS vs LUGAR_DE_ESTUDIO")
plt.xlabel("LUGAR_DE_ESTUDIO")
plt.ylabel("MEJORAS_SUGERIDAS")
plt.show()



#NUMERO 14
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar el dataset a trabajar
df = pd.read_csv("DATA_LUGARES_DE_ESTUDIO_V2.csv", delimiter=";")

#VERIFICAR SESGOS EN LA DATA

#SESGO DE SELECCION, mediante la variable carrera

#Calcular la moda de la variable carrera
moda_carrera=df['CARRERA'].mode()[0]
print("Carrera con mayor proporcion en la data: \n", moda_carrera)
print()
print()
contar_carreras=df.CARRERA.value_counts()

print(contar_carreras)


#Respuesta
print("Se evidencia un sesgo de seleccion en la data en este caso, el sesgo de selección se observa porque la muestra está fuertemente dominada por estudiantes de Ingeniería en Sistemas (111 registros),")
print("mientras que las demás carreras aparecen con frecuencias mucho menores. Esto significa que las conclusiones que se sacarán del análisis tenderán a reflejar sobre todo la perspectiva")
print("de quienes cursan Ingeniería en Sistemas, y no necesariamente la de todo el alumno de la institución. En otras palabras, la sobre-representación de una sola carrera")
print("sesga los resultados y puede llevar a interpretaciones poco precisas o no generalizables al resto de las carreras.")
# Out:
# Lugar de estudio más preferido por loes estudiantes Unisinuanos: Salón Vacío
#
#
#
#
#
#
#
# Lugares mas escogidos por carreras:
# CARRERA
# Administración de empresas    Salón Vacío
# Biología marina                Biblioteca
# Contaduría publica            Salón Vacío
# Derecho                       Salón Vacío
# Enfermeria                     Biblioteca
# Gastronomia                   Salón Vacío
# Ingeniería agroindustrial     Salón Vacío
# Ingeniería civil              Salón Vacío
# Ingeniería en sistemas        Salón Vacío
# Ingeniería industrial          Biblioteca
# Medicina                       Biblioteca
# Odontología                   Salón Vacío
# Optometría                     Biblioteca
# Psicología                     Biblioteca
# Name: LUGAR_DE_ESTUDIO, dtype: object
#
# LUGAR_DE_ESTUDIO
# Salón Vacío                        103
# Biblioteca                          74
# Salas con acceso a computadores     63
# Cafetería                           27
# Sala con acceso a computadoras      12
# Escaleras                            5
# Áreas verdes                         5
# Pasillos o corredores                5
# Sala de ABP                          4
# Cancha de futbol                     2
# Name: count, dtype: int64
# Promedio de horas de estudio de los estudiantes unisinuanos:
#  2.0566666666666666
#
#
# Promedio de horas por lugar de estudio:
#  LUGAR_DE_ESTUDIO
# Biblioteca                         1.972973
# Cafetería                          1.925926
# Cancha de futbol                   2.000000
# Escaleras                          1.200000
# Pasillos o corredores              1.800000
# Sala con acceso a computadoras     1.500000
# Sala de ABP                        1.500000
# Salas con acceso a computadores    2.174603
# Salón Vacío                        2.233010
# Áreas verdes                       1.800000
# Name: HORAS_DE_ESTUDIO, dtype: float64
#
# ¿Que carrera estudia mas en la unisinu?
#
#
# Promedio de horas de estudio por carrera:
#  CARRERA
# Administración de empresas    2.000000
# Biología marina               2.000000
# Contaduría publica            2.200000
# Derecho                       1.875000
# Enfermeria                    2.333333
# Gastronomia                   2.000000
# Ingeniería agroindustrial     1.416667
# Ingeniería civil              2.486486
# Ingeniería en sistemas        2.252252
# Ingeniería industrial         1.809524
# Medicina                      1.583333
# Odontología                   1.814815
# Optometría                    1.750000
# Psicología                    1.888889
# Name: HORAS_DE_ESTUDIO, dtype: float64
#
#
# Promedio de horas por carrera y lugar de estudio
#  CARRERA                     LUGAR_DE_ESTUDIO
# Administración de empresas  Escaleras                          1.000000
#                             Salón Vacío                        2.500000
# Biología marina             Biblioteca                         2.333333
#                             Escaleras                          1.000000
#                             Salón Vacío                        2.000000
#                                                                  ...
# Psicología                  Biblioteca                         2.000000
#                             Cafetería                          2.000000
#                             Pasillos o corredores              1.000000
#                             Salas con acceso a computadores    2.000000
#                             Salón Vacío                        2.000000
# Name: HORAS_DE_ESTUDIO, Length: 65, dtype: float64
#
#
#
# Mediana de las horas de estudio:
#  2.0
#
#
# Mediana de las horas de estudio por lugar de estudio:
#  LUGAR_DE_ESTUDIO
# Biblioteca                         2.0
# Cafetería                          2.0
# Cancha de futbol                   2.0
# Escaleras                          1.0
# Pasillos o corredores              2.0
# Sala con acceso a computadoras     1.5
# Sala de ABP                        1.5
# Salas con acceso a computadores    2.0
# Salón Vacío                        2.0
# Áreas verdes                       2.0
# Name: HORAS_DE_ESTUDIO, dtype: float64
#
#
# Media de las horas de eestudio:  2.0566666666666666
#
#
# Desviación estándar de las horas de estudio: 1.13
#
#
# Nivel de desviacion estandar de las horas de estudio: 54.960796769071884 %
#
#
# Puntuacion promedio de los lugares de estudio:  4.0633333333333335
#
# Puntuacion por lugar de estudio:
# LUGAR_DE_ESTUDIO
# Biblioteca                         4.135135
# Cafetería                          4.222222
# Cancha de futbol                   3.500000
# Escaleras                          3.800000
# Pasillos o corredores              4.000000
# Sala con acceso a computadoras     3.916667
# Sala de ABP                        4.750000
# Salas con acceso a computadores    3.968254
# Salón Vacío                        4.048544
# Áreas verdes                       4.000000
# Name: PUNTUACION, dtype: float64
# Cuartil del 25% 1.0
# Cuartil del 75% 2.0
# Límite inferior: -0.50, Límite superior: 3.50
# Valores atípicos detectados:
#       ID                 CARRERA  SEMESTRE                 LUGAR_DE_ESTUDIO  \
# 2      3        Ingeniería civil         5                      Salón Vacío
# 4      5  Ingeniería en sistemas         2                      Salón Vacío
# 8      9  Ingeniería en sistemas         3  Salas con acceso a computadores
# 11    12              Enfermeria         4                       Biblioteca
# 29    30        Ingeniería civil         3                      Salón Vacío
# 30    31  Ingeniería en sistemas         1                      Salón Vacío
# 33    34  Ingeniería en sistemas         5  Salas con acceso a computadores
# 36    37  Ingeniería en sistemas         1  Salas con acceso a computadores
# 47    48  Ingeniería en sistemas         5                      Salón Vacío
# 61    62        Ingeniería civil         1                       Biblioteca
# 72    73  Ingeniería en sistemas         1                       Biblioteca
# 75    76  Ingeniería en sistemas         1                      Salón Vacío
# 80    81  Ingeniería en sistemas         1  Salas con acceso a computadores
# 90    91  Ingeniería en sistemas         1  Salas con acceso a computadores
# 95    96                 Derecho         4                      Salón Vacío
# 109  110   Ingeniería industrial         1                        Cafetería
# 116  117        Ingeniería civil         4                       Biblioteca
# 156  157              Enfermeria         4                       Biblioteca
# 162  163  Ingeniería en sistemas         2                      Salón Vacío
# 167  168  Ingeniería en sistemas         2                       Biblioteca
# 171  172             Odontología         7  Salas con acceso a computadores
# 178  179  Ingeniería en sistemas         2                       Biblioteca
# 197  198  Ingeniería en sistemas         1                      Salón Vacío
# 199  200  Ingeniería en sistemas         4                      Salón Vacío
# 203  204  Ingeniería en sistemas         3                      Salón Vacío
# 206  207        Ingeniería civil         3  Salas con acceso a computadores
# 220  221  Ingeniería en sistemas         5                      Salón Vacío
# 227  228        Ingeniería civil         1  Salas con acceso a computadores
# 231  232        Ingeniería civil         3                      Salón Vacío
# 239  240             Odontología         3                      Salón Vacío
# 246  247              Optometría         5  Salas con acceso a computadores
# 263  264  Ingeniería en sistemas         4                      Salón Vacío
# 286  287             Odontología        10                      Salón Vacío
# 289  290  Ingeniería en sistemas         1                       Biblioteca
# 298  299        Ingeniería civil         6  Salas con acceso a computadores
#
#      HORAS_DE_ESTUDIO                                      MOTIVO_DE_USO  \
# 2                   4                    Ambiente tranquilo y silencioso
# 4                   4                    Ambiente tranquilo y silencioso
# 8                   5                    Ambiente tranquilo y silencioso
# 11                  4                     Disponibilidad de computadores
# 29                  6                    Ambiente tranquilo y silencioso
# 30                  4                    Ambiente tranquilo y silencioso
# 33                  4                     Disponibilidad de computadores
# 36                  6                     Disponibilidad de computadores
# 47                  4                    Ambiente tranquilo y silencioso
# 61                  4                           Mesas grandes diponibles
# 72                  6         Disponibilidad de acceso a internet rápido
# 75                  4  Cercanía a clases o facultad (Pasillos o corre...
# 80                  5                    Ambiente tranquilo y silencioso
# 90                  4         Disponibilidad de acceso a internet rápido
# 95                  4                    Ambiente tranquilo y silencioso
# 109                 6                     Acceso a comida y/o microondas
# 116                 4                           Mesas grandes diponibles
# 156                 4                    Ambiente tranquilo y silencioso
# 162                 5                    Ambiente tranquilo y silencioso
# 167                 5                    Ambiente tranquilo y silencioso
# 171                 4                    Ambiente tranquilo y silencioso
# 178                 4                    Ambiente tranquilo y silencioso
# 197                 6                    Ambiente tranquilo y silencioso
# 199                 5  Disponibilidad de espacio luego de terminar cl...
# 203                 4  Disponibilidad de espacio luego de terminar cl...
# 206                 4                     Disponibilidad de computadores
# 220                 4                    Ambiente tranquilo y silencioso
# 227                 6                    Ambiente tranquilo y silencioso
# 231                 4  Disponibilidad de espacio luego de terminar cl...
# 239                 4         Disponibilidad de acceso a internet rápido
# 246                 4  Cercanía a clases o facultad (Pasillos o corre...
# 263                 4                    Ambiente tranquilo y silencioso
# 286                 4                    Ambiente tranquilo y silencioso
# 289                 4                    Ambiente tranquilo y silencioso
# 298                 5                    Ambiente tranquilo y silencioso
#
#     PREFERENCIA_DE_USO         FRECUENCIA_DE_USO  PUNTUACION  \
# 2              Solo(a)  Varias veces a la semana           5
# 4               Pareja  Varias veces a la semana           5
# 8              Solo(a)  Varias veces a la semana           3
# 11              Pareja      2-3 veces por semana           5
# 29            En grupo  Varias veces a la semana           5
# 30            En grupo  Varias veces a la semana           5
# 33            En grupo      2-3 veces por semana           5
# 36             Solo(a)      2-3 veces por semana           4
# 47            En grupo            Ocasionalmente           4
# 61            En grupo      2-3 veces por semana           3
# 72              Pareja      2-3 veces por semana           5
# 75             Solo(a)       Una vez a la semana           5
# 80              Pareja  Varias veces a la semana           4
# 90            En grupo      2-3 veces por semana           5
# 95            En grupo                    Diario           4
# 109            Solo(a)                    Diario           4
# 116           En grupo                    Diario           5
# 156           En grupo  Varias veces a la semana           4
# 162           En grupo      2-3 veces por semana           5
# 167            Solo(a)            Ocasionalmente           5
# 171             Pareja      2-3 veces por semana           3
# 178             Pareja      2-3 veces por semana           4
# 197           En grupo  Varias veces a la semana           4
# 199             Pareja            Ocasionalmente           2
# 203             Pareja            Ocasionalmente           4
# 206           En grupo            Ocasionalmente           3
# 220           En grupo      2-3 veces por semana           4
# 227           En grupo      2-3 veces por semana           4
# 231             Pareja            Ocasionalmente           5
# 239           En grupo  Varias veces a la semana           2
# 246             Pareja      2-3 veces por semana           5
# 263           En grupo  Varias veces a la semana           3
# 286            Solo(a)  Varias veces a la semana           5
# 289            Solo(a)                    Diario           4
# 298           En grupo      2-3 veces por semana           5
#
#                   AREA_DE_ESTUDIO           MEJORAS_SUGERIDAS  \
# 2       Matemáticas y estadística  Sillas y mesas más cómodas
# 4         Ingeniería y tecnología                    Enchufes
# 8         Ingeniería y tecnología   Mejor conexión a internet
# 11       Salud y ciencias médicas   Mejor conexión a internet
# 29      Matemáticas y estadística          Reducción de ruido
# 30      Matemáticas y estadística   Mejor conexión a internet
# 33        Ingeniería y tecnología   Mejor conexión a internet
# 36        Ingeniería y tecnología   Mejor conexión a internet
# 47                    Humanidades   Mejor conexión a internet
# 61      Matemáticas y estadística                    Enchufes
# 72        Ingeniería y tecnología          Reducción de ruido
# 75          Educación y pedagogía  Sillas y mesas más cómodas
# 80        Ingeniería y tecnología   Mejor conexión a internet
# 90        Ingeniería y tecnología   Mejor conexión a internet
# 95              Ciencias sociales                 Ventilación
# 109     Matemáticas y estadística   Mejor conexión a internet
# 116       Ingeniería y tecnología          Reducción de ruido
# 156     Matemáticas y estadística                    Enchufes
# 162     Matemáticas y estadística                    Enchufes
# 167      Salud y ciencias médicas  Sillas y mesas más cómodas
# 171     Matemáticas y estadística                 Ventilación
# 178     Matemáticas y estadística   Mejor conexión a internet
# 197     Matemáticas y estadística   Mejor conexión a internet
# 199       Ingeniería y tecnología  Sillas y mesas más cómodas
# 203     Matemáticas y estadística                    Enchufes
# 206       Ingeniería y tecnología          Reducción de ruido
# 220     Matemáticas y estadística                    Enchufes
# 227      Salud y ciencias médicas                  Ilumiación
# 231  Ciencias naturales y exactas  Sillas y mesas más cómodas
# 239     Matemáticas y estadística                 Ventilación
# 246                   Humanidades   Mejor conexión a internet
# 263     Matemáticas y estadística  Sillas y mesas más cómodas
# 286      Salud y ciencias médicas          Reducción de ruido
# 289     Matemáticas y estadística   Mejor conexión a internet
# 298      Salud y ciencias médicas          Reducción de ruido
#
#               NUEVOS_ESPACIOS
# 2    Sí, cubículos personales
# 4    Sí, cubículos personales
# 8    Sí, cubículos personales
# 11   Sí, cubículos personales
# 29      Sí, espacios grupales
# 30      Sí, espacios grupales
# 33      Sí, espacios grupales
# 36      Sí, espacios grupales
# 47      Sí, espacios grupales
# 61      Sí, espacios grupales
# 72   Sí, cubículos personales
# 75                         No
# 80      Sí, espacios grupales
# 90      Sí, espacios grupales
# 95      Sí, espacios grupales
# 109  Sí, cubículos personales
# 116  Sí, cubículos personales
# 156     Sí, espacios grupales
# 162     Sí, espacios grupales
# 167     Sí, espacios grupales
# 171  Sí, cubículos personales
# 178     Sí, espacios grupales
# 197     Sí, espacios grupales
# 199     Sí, espacios grupales
# 203     Sí, espacios grupales
# 206  Sí, cubículos personales
# 220  Sí, cubículos personales
# 227     Sí, espacios grupales
# 231     Sí, espacios grupales
# 239     Sí, espacios grupales
# 246     Sí, espacios grupales
# 263  Sí, cubículos personales
# 286  Sí, cubículos personales
# 289  Sí, cubículos personales
# 298     Sí, espacios grupales
# Conteo de puntuacion:
#  PUNTUACION
# 5    111
# 4    104
# 3     78
# 2      7
# Name: count, dtype: int64
# ¿Que es lo que mas estudian los estudiantes Unisinuanos?
#
# AREA_DE_ESTUDIO
# Ingeniería y tecnología         101
# Matemáticas y estadística        92
# Salud y ciencias médicas         58
# Humanidades                      17
# Ciencias sociales                14
# Economía y administración         9
# Ciencias naturales y exactas      6
# Educación y pedagogía             2
# Arte y diseño                     1
# Name: count, dtype: int64
# Los estudiantes necesitan mas lugares de estudio? : Sí, espacios grupales
#
#
#
# Aunque la mayoria de los estudiantes consideran que necesitan más  Sí, espacios grupales Tambien se presentan las otras opiniones del resto de estudinates
# NUEVOS_ESPACIOS
# Sí, espacios grupales       152
# Sí, cubículos personales    128
# No                           20
# Name: count, dtype: int64
#
#
#
#
# Espacios más necesitados por carreras:
# CARRERA
# Administración de empresas       Sí, espacios grupales
# Biología marina                  Sí, espacios grupales
# Contaduría publica               Sí, espacios grupales
# Derecho                          Sí, espacios grupales
# Enfermeria                    Sí, cubículos personales
# Gastronomia                   Sí, cubículos personales
# Ingeniería agroindustrial     Sí, cubículos personales
# Ingeniería civil                 Sí, espacios grupales
# Ingeniería en sistemas           Sí, espacios grupales
# Ingeniería industrial         Sí, cubículos personales
# Medicina                      Sí, cubículos personales
# Odontología                      Sí, espacios grupales
# Optometría                       Sí, espacios grupales
# Psicología                    Sí, cubículos personales
# Name: NUEVOS_ESPACIOS, dtype: object
# ¿Qué mejoras sugieren los estudiantes? : Mejor conexión a internet
#
#
# Aunque la mayoría de los estudiantes sugieren  Mejor conexión a internet también se presentan otras opiniones:
# MEJORAS_SUGERIDAS
# Mejor conexión a internet     115
# Sillas y mesas más cómodas     74
# Reducción de ruido             32
# Enchufes                       28
# Ventilación                    26
# Decoración y ambiente          19
# Ilumiación                      4
# Mejores teclados                2
# Name: count, dtype: int64
#
#
# Conteo de mejoras sugeridas por carrera:
#
#
# Mejoras más sugeridas por carrera:
# CARRERA
# Administración de empresas     Mejor conexión a internet
# Biología marina                Mejor conexión a internet
# Contaduría publica             Mejor conexión a internet
# Derecho                        Mejor conexión a internet
# Enfermeria                     Mejor conexión a internet
# Gastronomia                    Mejor conexión a internet
# Ingeniería agroindustrial     Sillas y mesas más cómodas
# Ingeniería civil               Mejor conexión a internet
# Ingeniería en sistemas         Mejor conexión a internet
# Ingeniería industrial          Mejor conexión a internet
# Medicina                       Mejor conexión a internet
# Odontología                   Sillas y mesas más cómodas
# Optometría                    Sillas y mesas más cómodas
# Psicología                         Decoración y ambiente
# Name: MEJORAS_SUGERIDAS, dtype: object
# Carrera con mayor proporcion en la data:
#  Ingeniería en sistemas
#
#
# CARRERA
# Ingeniería en sistemas        111
# Ingeniería civil               37
# Odontología                    27
# Medicina                       24
# Ingeniería industrial          21
# Derecho                        16
# Ingeniería agroindustrial      12
# Gastronomia                    12
# Optometría                     12
# Psicología                      9
# Enfermeria                      6
# Biología marina                 5
# Contaduría publica              5
# Administración de empresas      3
# Name: count, dtype: int64
# Se evidencia un sesgo de seleccion en la data en este caso, el sesgo de selección se observa porque la muestra está fuertemente dominada por estudiantes de Ingeniería en Sistemas (111 registros),
# mientras que las demás carreras aparecen con frecuencias mucho menores. Esto significa que las conclusiones que se sacarán del análisis tenderán a reflejar sobre todo la perspectiva
# de quienes cursan Ingeniería en Sistemas, y no necesariamente la de todo el alumno de la institución. En otras palabras, la sobre-representación de una sola carrera
# sesga los resultados y puede llevar a interpretaciones poco precisas o no generalizables al resto de las carreras.
